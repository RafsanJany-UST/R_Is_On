# %%
df <- data.frame(
  team = c("A", "A", "B", "B", "C"),
  points = c(12, 15, 17, 24, 27),
  assists = c(4, 7, 7, 8, 12)
)

df
# Out:
#   team points assists
# 1 A    12      4
# 2 A    15      7
# 3 B    17      7
# 4 B    24      8
# 5 C    27     12

# %%
getwd()
# Out:
# [1] "c:/Users/user/Documents/GitHub/Project_rPPG"

# %%
"C:\Users\user\Desktop\R_exercise\R_exercise\apple_hair.txt"

# %%
df1<-read.table("C:\\Users\\user\\Desktop\\R_exercise\\R_exercise\\apple_hair.txt",sep="")

# %%
df1
# Out:
#    V1 V2   V3   V4    V5    V6    V7
# 1  1  37.0 37.3   0.3  2.24  3.18  0.94
# 2  1  49.0 50.4   1.4  9.56 10.83  1.27
# 3  1  34.0 37.0   3.0 25.77 23.19 -2.58
# 4  1  34.0 37.7   3.7  0.00  3.56  3.56
# 5  1  34.0 32.5  -1.5  7.56  7.31 -0.25
# 6  1  23.0 21.0  -2.0 16.35 13.77 -2.58
# 7  1  29.3 29.3   0.0  7.01 10.74  3.73
# 8  1  26.5 31.3   4.8 15.40 12.78 -2.62
# 9  1  35.3 37.7   2.4 13.24  5.69 -7.55
# 10 1  42.8 31.5 -11.3  4.76  2.67 -2.09
# 11 2  43.0 46.5   3.5 19.52 23.06  3.54
# 12 2  33.0 38.0   5.0 11.18  8.44 -2.74
# 13 2  31.7 39.0   7.3  7.13 13.00  5.87
# 14 2  29.3 47.6  18.3  0.85  3.97  3.12
# 15 2  39.8 54.3  14.5  0.73  2.26  1.53
# 16 2  37.3 44.0   6.7 10.28  7.16 -3.12
# 17 2  37.3 46.3   9.0  1.62  1.45 -0.17
# 18 2  30.7 30.0  -0.7  2.65  7.50  4.85
# 19 2  17.5 25.3   7.8  0.00  2.81  2.81
# 20 2  33.0 29.0  -4.0  3.93  7.04  3.11
# 21 2  36.0 42.0   6.0  5.00 11.69  6.69
# 22 2  42.0 46.5   4.5 12.13 12.35  0.22
# ...

# %%
df1 <- read.table(file.choose(),
                  sep = "")

# %%
df1
# Out:
#    V1 V2   V3   V4    V5    V6    V7
# 1  1  37.0 37.3   0.3  2.24  3.18  0.94
# 2  1  49.0 50.4   1.4  9.56 10.83  1.27
# 3  1  34.0 37.0   3.0 25.77 23.19 -2.58
# 4  1  34.0 37.7   3.7  0.00  3.56  3.56
# 5  1  34.0 32.5  -1.5  7.56  7.31 -0.25
# 6  1  23.0 21.0  -2.0 16.35 13.77 -2.58
# 7  1  29.3 29.3   0.0  7.01 10.74  3.73
# 8  1  26.5 31.3   4.8 15.40 12.78 -2.62
# 9  1  35.3 37.7   2.4 13.24  5.69 -7.55
# 10 1  42.8 31.5 -11.3  4.76  2.67 -2.09
# 11 2  43.0 46.5   3.5 19.52 23.06  3.54
# 12 2  33.0 38.0   5.0 11.18  8.44 -2.74
# 13 2  31.7 39.0   7.3  7.13 13.00  5.87
# 14 2  29.3 47.6  18.3  0.85  3.97  3.12
# 15 2  39.8 54.3  14.5  0.73  2.26  1.53
# 16 2  37.3 44.0   6.7 10.28  7.16 -3.12
# 17 2  37.3 46.3   9.0  1.62  1.45 -0.17
# 18 2  30.7 30.0  -0.7  2.65  7.50  4.85
# 19 2  17.5 25.3   7.8  0.00  2.81  2.81
# 20 2  33.0 29.0  -4.0  3.93  7.04  3.11
# 21 2  36.0 42.0   6.0  5.00 11.69  6.69
# 22 2  42.0 46.5   4.5 12.13 12.35  0.22
# ...

# %%
head(df1)
# Out:
#   V1 V2 V3   V4   V5    V6    V7
# 1 1  37 37.3  0.3  2.24  3.18  0.94
# 2 1  49 50.4  1.4  9.56 10.83  1.27
# 3 1  34 37.0  3.0 25.77 23.19 -2.58
# 4 1  34 37.7  3.7  0.00  3.56  3.56
# 5 1  34 32.5 -1.5  7.56  7.31 -0.25
# 6 1  23 21.0 -2.0 16.35 13.77 -2.58

# %% [markdown]
# # Cell 1 – Simple Math in R

# %%
3 + 5
12 + 3 / 4 - 5 + 3 * 8
(12 + 3 / 4 - 5) + 3 * 8
pi * 2^3 - sqrt(4)
log(2, base = 10)

A <- 6 + 8
a   # will give error: object 'a' not found (case-sensitive)
A   # 14
# Out:
# [1] 8
# [1] 31.75
# [1] 31.75
# [1] 23.13274
# [1] 0.30103
# Error: object 'a' not found
# Traceback:

# %% [markdown]
# # Cell 2 – Entering Vectors (Numeric & Character)

# %%
# numeric vector
numeric_values <- c(1, 3, 5, 8, 9)

# check class
class(numeric_values)

# print vector
numeric_values

# 4th element
numeric_values[4]


# character vector
char_values <- c("Bob", "Mike", "Tony", "Andy")

# check class
class(char_values)

# print vector
char_values
# Out:
# [1] "numeric"
# [1] 1 3 5 8 9
# [1] 8
# [1] "character"
# [1] "Bob"  "Mike" "Tony" "Andy"

# %% [markdown]
# # Cell 3 – Creating a Data Frame Manually

# %%
# create data frame
df <- data.frame(
  team    = c("A", "A", "B", "B", "C"),
  points  = c(12, 15, 17, 24, 27),
  assists = c(4, 7, 7, 8, 12)
)

# display data frame
df

# check class
class(df)

# value in 4th row, 3rd column
df[4, 3]
# Out:
#   team points assists
# 1 A    12      4
# 2 A    15      7
# 3 B    17      7
# 4 B    24      8
# 5 C    27     12
# [1] "data.frame"
# [1] 8

# %% [markdown]
# # Cell 4 – Creating a Matrix from Vectors

# %%
# vectors
points  <- c(12, 15, 17, 24, 27)
assists <- c(4, 7, 7, 8, 12)

# bind columns into matrix
mat <- cbind(points, assists)

# show matrix
mat

# value in 4th row, 2nd column
mat[4, 2]
# Out:
#      points assists
# [1,] 12      4
# [2,] 15      7
# [3,] 17      7
# [4,] 24      8
# [5,] 27     12
# assists
#       8

# %% [markdown]
# # Cell 5 – Working Directory & Workspace

# %%
# show current working directory
getwd()

# change working directory (example – adjust to your path)
#setwd("C:/Users/user/Desktop/R_exercise/R_exercise")

# list objects in workspace
ls()
# Out:
# [1] "c:/Users/RAZER/Documents/GitHub_2/R_Is_On/CODE"
# [1] "A"              "assists"        "char_values"    "df"
# [5] "mat"            "numeric_values" "points"

# %% [markdown]
# # Cell 6 – Reading a Text File with read.table (BMI example)

# %%
df1 <- read.table(
  "C:\\Users\\RAZER\\Documents\\GitHub_2\\R_Is_On\\R_exercise_Data\\R_exercise\\bmi.txt",
  sep = "",
  col.names = c("height", "weight", "year", "religion", "gender", "marriage")
)

# first few rows
head(df1)

# element at row 1, column 2
df1[1, 2]

# entire second row
df1[2, ]

# first 5 height values
df1$height[1:5]

# same using [row, column]
df1[1:5, 1]
# Out:
#   height weight year religion gender marriage
# 1 167    68     1974 No       F      N
# 2 162    49     1974 C2       F      N
# 3 158    50     1978 C2       F      N
# 4 165    56     1977 No       F      N
# 5 160    52     1959 No       F      N
# 6 162    52     1972 No       F      Y
# [1] 68
#   height weight year religion gender marriage
# 2 162    49     1974 C2       F      N
# [1] 167 162 158 165 160
# [1] 167 162 158 165 160

# %% [markdown]
# # Cell 7 – Attaching a Data Frame

# %% [markdown]
# ## <font color = red>Question</font> What is the `detach`?

# %%
# continue from df1 above
attach(df1)

height    # prints the 'height' column

# when you’re done, it’s safer to detach
detach(df1)
# Out:
#   [1] 167 162 158 165 160 162 162 167 156 157 158 155 160 153 162 163 165 162
#  [19] 162 172 158 153 156 168 168 158 160 162 162 164 173 161 165 160 164 167
#  [37] 162 164 161 170 168 163 158 160 158 163 160 158 158 168 155 160 163 157
#  [55] 160 165 167 162 159 157 160 162 158 155 153 160 160 160 163 158 158 162
#  [73] 163 165 169 155 155 160 156 176 163 161 157 165 160 170 156 162 167 161
#  [91] 160 165 165 165 163 166 168 170 170 153 152 164 158 160 165 164 166 163
# [109] 158 160 165 165 160 158 163 158 164 154 168 164 180 160 175 170 175 160
# [127] 169 165 150 165 165 158 165 160 168 168 159 160 155 164 162 160 155 160
# [145] 162 160 164 162 161 163 166 167 160 152 153 156 170 165 161 161 150 164
# [163] 162 155 179 152 160 173 174 178 158 155 164 163 160 160 166

# %% [markdown]
# # Cell 8 – Basic Statistics with chickwts Dataset

# %%
# built-in dataset
head(chickwts)

# quantiles
quantile(chickwts[, 1])
quantile(chickwts$weight, probs = 0.05)

# mean
mean(chickwts$weight)
mean(chickwts$weight, trim = 0.05)

# median
median(chickwts$weight)

# variance & standard deviation
var(chickwts$weight)
sd(chickwts$weight)
sqrt(var(chickwts$weight))   # same as sd
# Out:
#   weight feed
# 1 179    horsebean
# 2 160    horsebean
# 3 136    horsebean
# 4 227    horsebean
# 5 217    horsebean
# 6 168    horsebean
#    0%   25%   50%   75%  100%
# 108.0 204.5 258.0 323.5 423.0
#    5%
# 140.5
# [1] 261.3099
# [1] 261.0154
# [1] 258
# [1] 6095.503
# [1] 78.0737
# [1] 78.0737

# %% [markdown]
# # Cell 9 – Range & IQR (Interquartile Range)

# %%
# range (min, max)
range(chickwts$weight)

# max - min
max(chickwts$weight) - min(chickwts$weight)

# using diff()
diff(range(chickwts$weight))

# IQR
IQR(chickwts$weight)
# Out:
# [1] 108 423
# [1] 315
# [1] 315
# [1] 119

# %% [markdown]
# # Cell 10 – Frequency Tables & Pie Charts

# %%
# frequency table for feed type
table(chickwts$feed)

# add margins (totals)
addmargins(table(chickwts$feed))

# add margins with mean (not very meaningful here, but matches slide idea)
addmargins(table(chickwts$feed), FUN = mean)

# pie charts
par(mfrow = c(1, 2))

pie(table(chickwts$feed))

pie(
  table(chickwts$feed),
  col = rainbow(length(unique(chickwts$feed)))
)
# Out:
#    casein horsebean   linseed  meatmeal   soybean sunflower
#        12        10        12        11        14        12
#    casein horsebean   linseed  meatmeal   soybean sunflower       Sum
#        12        10        12        11        14        12        71
#    casein horsebean   linseed  meatmeal   soybean sunflower      mean
#  12.00000  10.00000  12.00000  11.00000  14.00000  12.00000  11.83333
# plot without title

# %% [markdown]
# # Cell 11 – Barplot, Histogram, Boxplot

# %%
# barplot of feed frequencies
barplot(table(chickwts$feed), col = 2:7)
barplot(table(chickwts$feed), col = 2:7, horiz = TRUE)

# histogram of weight
hist(chickwts$weight)
hist(
  chickwts$weight,
  prob = TRUE,
  main = "weight of chick",
  xlab = "weight"
)

# boxplots
boxplot(chickwts$weight)

boxplot(weight ~ feed, data = chickwts)
# Out:
# plot without title
# plot without title
# Plot with title "Histogram of chickwts$weight"
# Plot with title "weight of chick"
# plot without title
# plot without title
